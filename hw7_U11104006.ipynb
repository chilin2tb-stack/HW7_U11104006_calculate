# %%
import numpy as np

# %%
lon = 12.1878; lat =48.1195; ele=487.9; Go=980717.39

# %%
Ge =978031.85

# %%
np.pi
# Out:
# 3.141592653589793

# %%
fac =np.pi/180.0

# %%
print(np.sin(90*fac))
# Out:
# 1.0

# %%
Gt = Ge *(1+0.00578895*np.sin(lat*fac)**2+0.000023462*np.sin(lat*fac)**4)

# %%
print(f"theoretical gravity:{Gt}")
# Out:
# theoretical gravity:981177.4397522432

# %%
FAC = 0.3086 * ele
print(f"(a-ii) Free Air Correction (FAC): {FAC:.2f} mGal")
# Out:
# (a-ii) Free Air Correction (FAC): 150.57 mGal

# %%
BC = 0.112*ele
print(f"(a-iii) Bouguer Correction (BC): {BC:.2f} mGal")
# Out:
# (a-iii) Bouguer Correction (BC): 54.64 mGal

# %%
FAA = Go - Gt + FAC
print(f"(a-iv) Free Air Anomaly (FAA): {FAA:.2f} mGal")
# Out:
# (a-iv) Free Air Anomaly (FAA): -309.48 mGal

# %%
BGA = FAA - BC
print(f"(a-v) Bouguer Gravity Anomaly (BGA): {BGA:.2f} mGal")
# Out:
# (a-v) Bouguer Gravity Anomaly (BGA): -364.13 mGal

# %%
h_ocean = 0.0    # 測站高程 (Station elevation is 0 m at sea surface)
d_water = ele    # 水深 (Water depth in m), 根據題目 d = 487.9 m
